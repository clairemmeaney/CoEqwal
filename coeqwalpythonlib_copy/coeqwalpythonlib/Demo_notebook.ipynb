# %%
from myfunctions import *

# %%
df, dss_names = read_in_df('/Users/clairemarie/Desktop/CoEqwal/Correct Folder Nesting/output/convert/convert_EDA_data_10_01_24.csv','/Users/clairemarie/Desktop/CoEqwal/Correct Folder Nesting/data/metrics/EDA_10_01_24_dss_names.csv')
df.head()
# Out:
# A                    CALSIM                                   \
# B          COREQSACDV_S0000 CO_EC_MONTH_S0000 C_AMR004_S0000
# C                      FLOW          SALINITY        CHANNEL
# D                      1MON              1MON           1MON
# E                    L2020A            L2020A         L2020A
# F                  PER-AVER          PER-AVER       PER-AVER
# Units                   CFS          UMHOS/CM            CFS
# 1921-10-31              0.0         2173.8484      3413.1506
# 1921-11-30              0.0         1444.8396      1879.9095
# 1921-12-31              0.0         3810.6936      2018.9040
# 1922-01-31              0.0         6766.5405      1700.1637
# 1922-02-28              0.0         1916.7603      3810.1155
#
# A                                                                \
# B          C_CAA003_CVP_S0000 C_CAA003_SWP_S0000 C_CHW017_S0000
# C               FLOW-DELIVERY      FLOW-DELIVERY        CHANNEL
# D                        1MON               1MON           1MON
# E                      L2020A             L2020A         L2020A
# F                    PER-AVER           PER-AVER       PER-AVER
# Units                     CFS                CFS            CFS
# 1921-10-31             0.0000          2386.0586       0.000000
# 1921-11-30          1992.1262          3152.6128       0.084717
# 1921-12-31             0.0000          7400.6836       6.398305
# 1922-01-31             0.0000          3135.4710       6.022529
# 1922-02-28             0.0000          5207.1123     393.907380
#
# A                                                                      ...  \
# B          C_CLV004_S0000 C_DMC003_S0000 C_EBP016_S0000 C_FOLSM_S0000  ...
# C                 CHANNEL        CHANNEL        CHANNEL       CHANNEL  ...
# D                    1MON           1MON           1MON          1MON  ...
# E                  L2020A         L2020A         L2020A        L2020A  ...
# F                PER-AVER       PER-AVER       PER-AVER      PER-AVER  ...
# Units                 CFS            CFS            CFS           CFS  ...
# 1921-10-31       0.958765       800.0000      11.597759     3617.7950  ...
# 1921-11-30       0.046577      4598.6390      18.277239     2016.0187  ...
# 1921-12-31     179.064130      4598.6080     509.976840     1934.8564  ...
# 1922-01-31      39.184666      4598.2017      98.915190     1730.9570  ...
# 1922-02-28    1826.513000      4597.0503     645.834170     3751.4626  ...
#
# A                                                           \
# B          DEL_CVP_TOTAL_S_S0005_TAF DEL_SWP_PIN_S0005_TAF
# C                       DELIVERY-CVP          DELIVERY-SWP
# D                               1MON                  1MON
# E                             L2020A                L2020A
# F                           PER-AVER              PER-AVER
# Units                            TAF                   TAF
# 1921-10-31                217.099912              1.429997
# 1921-11-30                115.100017              1.429997
# 1921-12-31                 85.233680              9.139983
# 1922-01-31                104.435579              9.139983
# 1922-02-28                 60.858843              0.000000
#
# A                                                          \
# B          DEL_SWP_TOTA_S0005_TAF DEL_SWP_TOT_S_S0005_TAF
# C                    DELIVERY-SWP            DELIVERY-SWP
# D                            1MON                    1MON
# E                          L2020A                  L2020A
# F                        PER-AVER                PER-AVER
# Units                         TAF                     TAF
# 1921-10-31             352.153587              350.688568
# 1921-11-30             304.954936              303.321949
# 1921-12-31             282.815807              281.128812
# 1922-01-31              55.064762               53.377766
# 1922-02-28              50.578084               49.054088
#
# A                                                                    \
# B          DEL_TOT_PSC_N_S0005_TAF NDO_S0005_TAF NDOI_ADD_S0005_TAF
# C                     DELIVERY-TOT      FLOW-NDO               FLOW
# D                             1MON          1MON               1MON
# E                           L2020A        L2020A             L2020A
# F                         PER-AVER      PER-AVER           PER-AVER
# Units                          TAF           TAF                TAF
# 1921-10-31               64.167303    576.445248           0.000000
# 1921-11-30               90.022551    277.838279          10.070148
# 1921-12-31               65.079014    935.193043         658.499324
# 1922-01-31               26.766970    967.108311         598.183352
# 1922-02-28                2.640140   2653.430286        2020.307454
#
# A
# B          NDOI_ADD_CVP_S0005_TAF NDOI_MIN_S0005_TAF SWPTOTALDEL_S0005_TAF
# C                    FLOW-CHANNEL               FLOW         FLOW-DELIVERY
# D                            1MON               1MON                  1MON
# E                          L2020A             L2020A                L2020A
# F                        PER-AVER           PER-AVER              PER-AVER
# Units                         TAF                TAF                   TAF
# 1921-10-31               0.000000         576.445248            352.992731
# 1921-11-30               0.000000         267.768115            305.068713
# 1921-12-31             323.656864         276.693719            289.158568
# 1922-01-31             304.481411         368.924959             63.792180
# 1922-02-28            1117.313515         633.122832             52.002164
#
# [5 rows x 956 columns]

# %%
# Shasta Annual Avg.
shasta_ann_avg_df = ann_avg(df, dss_names, "S_SHSTA_", "TAF")
shasta_ann_avg_df.head()
# Out:
#    Ann_Avg_S_SHSTA_
# 0       3333.248068
# 1       3330.685860
# 2       3219.552636
# 3       2943.619492
# 4       2818.559097

# %%
# Shasta Annual 10th percentile
shasta_10_pct = ann_pct(df, dss_names, 0.1, "S_SHSTA_", "TAF", "10per_S_SHSTA_TAF")
shasta_10_pct
# Out:
#    10per_S_SHSTA_TAF
# 0       30085.857350
# 1       29316.302430
# 2       26172.808557
# 3       19728.947056
# 4       18219.710851
# 5       16755.082256

# %%
# Shasta April Avg
shasta_apr_avg = mnth_avg(df, dss_names, "S_SHSTA_", "TAF", 4)
shasta_apr_avg
# Out:
#    Apr_Avg_S_SHSTA_
# 0       4057.809370
# 1       4048.634597
# 2       3932.366307
# 3       3717.534064
# 4       3602.118295
# 5       3528.082795

# %%
# Shasta all month Avg's
shasta_moy_avgs = moy_avgs(df, dss_names, "S_SHSTA_", "TAF")
shasta_moy_avgs
# Out:
#    Month  Avg_S_SHSTA_
# 0    Jan   2974.554646
# 1    Feb   3216.693033
# 2    Mar   3554.839743
# 3    Apr   3814.424238
# 4    May   3797.794530
# 5    Jun   3523.633533
# 6    Jul   3008.947120
# 7    Aug   2691.566440
# 8    Sep   2541.495041
# 9    Oct   2484.668412
# 10   Nov   2487.640510
# 11   Dec   2681.218551

# %%
# Shasta Apr 10th percentile
#
# [1200 rows x 0 columns]

# %%
subset_df = create_subset_unit(df, "DEL_SWP_TOTAL", "TAF")
subset_df.index.year
# Out:
# Index([1921, 1921, 1921, 1922, 1922, 1922, 1922, 1922, 1922, 1922,
#        ...
#        2020, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021],
#       dtype='int32', length=1200)

# %%
var_df = create_subset_unit(df, "S_SHASTA_", "TAF")
all_years_totals = [var_df.index.year]
for year in var_df.index.year:
    metrics = []
    # for each study in dss_name
    for study_index in np.arange(0, len(dss_names)):
# Out:
# [Index([1921, 1921, 1921, 1922, 1922, 1922, 1922, 1922, 1922, 1922,
#         ...
#         2020, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021],
#        dtype='int32', length=1200)]

# %%
var_df = create_subset_unit(df, "S_SHASTA_", "TAF")
all_years_totals = var_df.index.year.tolist()
# range(1, len(var_df.index.year))
#for year in var_df.index.year:
for year in all_years_totals:
    metrics = []
    for study_index in np.arange(0, len(dss_names)):
        #metric_val = compute_annual_sums(var_df, "S_SHASTA_", study_index, "TAF", months=None)
        metrics.append(metric_val)
metrics
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 8
#       6     metrics = []
#       7     for study_index in np.arange(0, len(dss_names)):
# ----> 8         metric_val = compute_annual_sums(var_df, "S_SHASTA_", study_index, "TAF", months=None)
#       9         metrics.append(metric_val)
#      10 metrics
#
# File ~/Desktop/CoEqwal/CoEqwal/coeqwalpythonlib_copy/coeqwalpythonlib/myfunctions.py:342, in compute_annual_sums(df, var, study_lst, units, months)
#     341 def compute_annual_sums(df, var, study_lst, units, months):
# --> 342     subset_df = create_subset_unit(df, var, units).iloc[:, study_lst]
#     343     subset_df = add_water_year_column(subset_df)
#     345     if months is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexing.py:1594, in _iLocIndexer._getitem_tuple(self, tup)
#    1593 def _getitem_tuple(self, tup: tuple):
# -> 1594     tup = self._validate_tuple_indexer(tup)
#    1595     with suppress(IndexingError):
#    1596         return self._getitem_lowerdim(tup)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexing.py:904, in _LocationIndexer._validate_tuple_indexer(self, key)
#     902 for i, k in enumerate(key):
#     903     try:
# --> 904         self._validate_key(k, i)
#     905     except ValueError as err:
#     906         raise ValueError(
#     907             "Location based indexing can only have "
#     908             f"[{self._valid_types}] types"
#     909         ) from err
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexing.py:1496, in _iLocIndexer._validate_key(self, key, axis)
#    1494     return
#    1495 elif is_integer(key):
# -> 1496     self._validate_integer(key, axis)
#    1497 elif isinstance(key, tuple):
#    1498     # a tuple should already have been caught by this point
#    1499     # so don't treat a tuple as a valid indexer
#    1500     raise IndexingError("Too many indexers")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexing.py:1589, in _iLocIndexer._validate_integer(self, key, axis)
#    1587 len_axis = len(self.obj._get_axis(axis))
#    1588 if key >= len_axis or key < -len_axis:
# -> 1589     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds
