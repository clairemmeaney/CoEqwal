# %%
from metricfunctions import *

# %%
df, dss_names = read_in_df('/Users/clairemarie/Desktop/CoEqwal/Correct Folder Nesting/output/convert/convert_EDA_data_10_01_24.csv','/Users/clairemarie/Desktop/CoEqwal/Correct Folder Nesting/data/metrics/EDA_10_01_24_dss_names.csv')
df.head()
# Out:
# A                    CALSIM                                   \
# B          COREQSACDV_S0000 CO_EC_MONTH_S0000 C_AMR004_S0000
# C                      FLOW          SALINITY        CHANNEL
# D                      1MON              1MON           1MON
# E                    L2020A            L2020A         L2020A
# F                  PER-AVER          PER-AVER       PER-AVER
# Units                   CFS          UMHOS/CM            CFS
# 1921-10-31              0.0         2173.8484      3413.1506
# 1921-11-30              0.0         1444.8396      1879.9095
# 1921-12-31              0.0         3810.6936      2018.9040
# 1922-01-31              0.0         6766.5405      1700.1637
# 1922-02-28              0.0         1916.7603      3810.1155
#
# A                                                                \
# B          C_CAA003_CVP_S0000 C_CAA003_SWP_S0000 C_CHW017_S0000
# C               FLOW-DELIVERY      FLOW-DELIVERY        CHANNEL
# ...

# %%
# Shasta Annual Avg.
shasta_ann_avg_df = ann_avg(df, dss_names, "S_SHSTA_", "TAF")
shasta_ann_avg_df.head()
# Out:
#    Ann_Avg_S_SHSTA_
# 0       3333.248068
# 1       3330.685860
# 2       3219.552636
# 3       2943.619492
# 4       2818.559097

# %%
# Shasta Annual 10th percentile
shasta_10_pct = ann_pct(df, dss_names, 0.1, "S_SHSTA_", "TAF", "10per_S_SHSTA_TAF")
shasta_10_pct
# Out:
#    10per_S_SHSTA_TAF
# 0       30085.857350
# 1       29316.302430
# 2       26172.808557
# 3       19728.947056
# 4       18219.710851
# 5       16755.082256

# %%
# Shasta April Avg
shasta_apr_avg = mnth_avg(df, dss_names, "S_SHSTA_", "TAF", 4)
shasta_apr_avg
# Out:
#    Apr_Avg_S_SHSTA_
# 0       4057.809370
# 1       4048.634597
# 2       3932.366307
# 3       3717.534064
# 4       3602.118295
# 5       3528.082795

# %%
# Shasta all month Avg's
shasta_moy_avgs = moy_avgs(df, dss_names, "S_SHSTA_", "TAF")
shasta_moy_avgs
# Out:
#    Month  Avg_S_SHSTA_
# 0    Jan   2974.554646
# 1    Feb   3216.693033
# 2    Mar   3554.839743
# 3    Apr   3814.424238
# 4    May   3797.794530
# 5    Jun   3523.633533
# 6    Jul   3008.947120
# 7    Aug   2691.566440
# 8    Sep   2541.495041
# 9    Oct   2484.668412
# 10   Nov   2487.640510
# 11   Dec   2681.218551

# %%
# Shasta Apr 10th percentile
shasta_apr_10_pct = mnth_pct(df, dss_names, "S_SHSTA_", 0.1, "TAF", "S_SHASTA_10_pct", 4)
shasta_apr_10_pct
# Out:
#    S_SHASTA_10_pct
# 0       3138.96662
# 1       2988.21141
# 2       2804.26550
# 3       2388.42869
# 4       2174.41759
# 5       1981.23583

# %%
# Shasta annual totals
shasta_ann_totals = annual_totals(df, "S_SHSTA_", "TAF")
shasta_ann_totals
# Out:
# A            CALSIM                                                          \
# B     S_SHSTA_S0000 S_SHSTA_S0001 S_SHSTA_S0002 S_SHSTA_S0003 S_SHSTA_S0004
# C           STORAGE       STORAGE       STORAGE       STORAGE       STORAGE
# D              1MON          1MON          1MON          1MON          1MON
# E            L2020A        L2020A        L2020A        L2020A        L2020A
# F          PER-AVER      PER-AVER      PER-AVER      PER-AVER      PER-AVER
# Units           TAF           TAF           TAF           TAF           TAF
# Year
# 1921      8591.9769     9035.1000    9028.54150    9069.73850    9014.75460
# 1922     44681.5674    45079.8841   44826.27550   43330.45040   42950.60320
# 1923     42369.3594    42768.3380   41640.16810   40046.96810   39604.99670
# 1924     26484.1924    26216.5829   20428.37879   17530.07363   17913.67523
# 1925     40028.5909    36689.4696   33882.09200   29517.43820   27757.88540
# ...
